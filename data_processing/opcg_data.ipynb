# %% [markdown]
# # NOTES
# ## TODO
# - Replace Cost = '-' with '0' ***done***

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_json('data/raw/card_output.json')
data = pd.DataFrame(data)
df = data.copy()

# %%
df
# Out:
#                               card_name      card_id  \
# 0     Just Shut Up and Come with Us!!!!  EB01-009_p1
# 1     Just Shut Up and Come with Us!!!!  EB01-009_r1
# 2                             Cavendish  EB01-012_r1
# 3                       Scratchmen Apoo  EB01-015_p5
# 4                       Scratchmen Apoo  EB01-015_r1
# ...                                 ...          ...
# 3494                      Trafalgar Law  ST03-008_p1
# 3495                             Yamato  ST09-012_p1
# 3496                              Jinbe  ST10-005_p1
# 3497                     Monkey.D.Luffy  ST10-006_p2
# 3498                     Monkey.D.Luffy  ST21-001_p2
#
#                                       set_name rarity   color  card_type  \
# 0     -ONE PIECE CARD THE BEST vol.2- [PRB-02]      C     Red      EVENT
# 1     -ONE PIECE CARD THE BEST vol.2- [PRB-02]      C     Red      EVENT
# 2     -ONE PIECE CARD THE BEST vol.2- [PRB-02]     SR   Green  CHARACTER
# ...

# %%
# Replace '-' with 0
df['cost'] = df['cost'].replace('-', 0)

# %%
def data_processing(df):
    # Replace '-' with 0
    df['cost'] = df['cost'].replace('-', 0)

    return df
